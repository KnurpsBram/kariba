# %% [markdown]
# ## AI plays Kariba!
#
# The rules of Kariba are fairly simple:
#
# When it's your turn you play one or several cards of the same species from your hand onto the field. If at some point there are 3 or more animals of the same species on the field, they chase away the closest weaker animal. However, everyone knows elephants are afraid of mice, so the mouse is the only animal that can chase away the elephant. For every animal you chase away, you get a point.
# <br>
# And that's it!
# <br>
# The deck starts out with 64 cards (8 animals for each of the 8 species) and the game ends when the deck and one of the player's hands is empty. Before your turn you can refill your hand up to 5 cards.
#
# 8: Elephant<br>
# 7: Rhino<br>
# 6: Leopard<br>
# 5: Ostrich<br>
# 4: Giraffe<br>
# 3: Zebra<br>
# 2: Meerkat<br>
# 1: Mouse<br>
#
# The AI you will be playing against uses Monte Carlo Tree Search (MCTS), this means that it can plan ahead before it plays a move. However, it's not a learning algorithm, so after each move it forgets everything it knows and restarts from scratch. The AI cannot see the cards in your hand, but it does know what cards have left the game, so it could potentially infer whether the deck has run out of mice, for instance. If you choose not to view the opponent's hands, but do choose to view the contents of the deck, what you'll see will actually be the union of the deck and all the opponent's hands.
#
# You can play a move by typing for example "3 giraffes" (other ways to play that move are "3giraffes", "3 Giraffes", "3 giraffe", "3*4" and "00030000")
#
# Good luck!

# %%
import interactive_game

# %%
interactive_game.interactive_game(n=100) # higher value for n will make MCTS better, but it will take more time
# Out:
# Okay Human! what is your name? y
# Do you want the AI's cards to be visible to you? (y/n)y
# Do you want the contents of the deck to be visible to you? (y/n)y
# Okay, let's flip a coin to see who may begin the game
# Very well!  Monty Carlos  may begin!
#
# --------------------------------------------------------
# Monty Carlos drew the following cards:
#     1 elephant
#     1 rhino
#     1 ostrich
#     1 zebra
#     1 mouse
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 369.23it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 ostrich
#
# --------------------------------------------------------
# y drew the following cards:
#     1 leopard
#     1 ostrich
#     1 giraffe
#     1 meerkat
#     1 mouse
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     2 elephants
#     2 rhinos
#     2 leopards
#     1 ostrich
#     2 giraffes
#     2 zebras
#     2 meerkats
#     1 mouse
#
# On the field lies:
#     1 ostrich
#
# Monty Carlos's hand holds:
#     1 elephant
#     1 rhino
#     1 zebra
#     1 mouse
#
# y's hand holds:
#     1 leopard
#     1 ostrich
#     1 giraffe
#     1 meerkat
#     1 mouse
#
# What's your move?1 ostrich
# --------------------------------------------------------
# y played:
#     1 ostrich
#
# --------------------------------------------------------
# Monty Carlos drew the following card:
#     1 leopard
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 409.15it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 leopard
#
# --------------------------------------------------------
# y drew the following card:
#     1 ostrich
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     2 elephants
#     2 rhinos
#     1 leopard
#     2 giraffes
#     2 zebras
#     2 meerkats
#     1 mouse
#
# On the field lies:
#     1 leopard
#     2 ostriches
#
# Monty Carlos's hand holds:
#     1 elephant
#     1 rhino
#     1 zebra
#     1 mouse
#
# y's hand holds:
#     1 leopard
#     1 ostrich
#     1 giraffe
#     1 meerkat
#     1 mouse
#
# What's your move?1 ostrich
# --------------------------------------------------------
# y played:
#     1 ostrich
#
# --------------------------------------------------------
# Monty Carlos drew the following card:
#     1 leopard
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 408.82it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 elephant
#
# --------------------------------------------------------
# y drew the following card:
#     1 zebra
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     2 elephants
#     2 rhinos
#     2 giraffes
#     1 zebra
#     2 meerkats
#     1 mouse
#
# On the field lies:
#     1 elephant
#     1 leopard
#     3 ostriches
#
# Monty Carlos's hand holds:
#     1 rhino
#     1 leopard
#     1 zebra
#     1 mouse
#
# y's hand holds:
#     1 leopard
#     1 giraffe
#     1 zebra
#     1 meerkat
#     1 mouse
#
# What's your move?1 giraffe
# --------------------------------------------------------
# y played:
#     1 giraffe
#
# --------------------------------------------------------
# Monty Carlos drew the following card:
#     1 zebra
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 466.42it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 rhino
#
# --------------------------------------------------------
# y drew the following card:
#     1 meerkat
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     2 elephants
#     2 rhinos
#     2 giraffes
#     1 meerkat
#     1 mouse
#
# On the field lies:
#     1 elephant
#     1 rhino
#     1 leopard
#     3 ostriches
#     1 giraffe
#
# Monty Carlos's hand holds:
#     1 leopard
#     2 zebras
#     1 mouse
#
# y's hand holds:
#     1 leopard
#     1 zebra
#     2 meerkats
#     1 mouse
#
# What's your move?2 meerkats
# --------------------------------------------------------
# y played:
#     2 meerkats
#
# --------------------------------------------------------
# Monty Carlos drew the following card:
#     1 meerkat
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 522.37it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 zebra
#
# --------------------------------------------------------
# y drew the following cards:
#     1 elephant
#     1 mouse
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     1 elephant
#     2 rhinos
#     2 giraffes
#
# On the field lies:
#     1 elephant
#     1 rhino
#     1 leopard
#     3 ostriches
#     1 giraffe
#     1 zebra
#     2 meerkats
#
# Monty Carlos's hand holds:
#     1 leopard
#     1 zebra
#     1 meerkat
#     1 mouse
#
# y's hand holds:
#     1 elephant
#     1 leopard
#     1 zebra
#     2 mice
#
# What's your move?2 mice
# --------------------------------------------------------
# y played:
#     2 mice
#
# --------------------------------------------------------
# Monty Carlos drew the following card:
#     1 elephant
#
# Monty Carlos is planning its next move...
# 100%|██████████| 100/100 [00:00<00:00, 561.98it/s]
# --------------------------------------------------------
# Monty Carlos played:
#     1 zebra
#
# --------------------------------------------------------
# y drew the following cards:
#     1 rhino
#     1 giraffe
#
# ********************************************************
# Scoreboard:
#     y            : 0
#     Monty Carlos : 0
#
# The deck holds:
#     1 rhino
#     1 giraffe
#
# On the field lies:
#     1 elephant
#     1 rhino
#     1 leopard
#     3 ostriches
#     1 giraffe
#     2 zebras
#     2 meerkats
#     2 mice
#
# Monty Carlos's hand holds:
#     1 elephant
#     1 leopard
#     1 meerkat
#     1 mouse
#
# y's hand holds:
#     1 elephant
#     1 rhino
#     1 leopard
#     1 giraffe
#     1 zebra

# %% [markdown]
# ##
